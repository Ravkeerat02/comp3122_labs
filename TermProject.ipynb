# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravkeerat02/comp3122_labs/blob/master/TermProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# import matplotlib.pyplot as plt

# %% [markdown]
# Student Name - Ravkeerat Singh
# <br>
# Student ID - 101344680
# <BR>
# Final Project Alternaive 1

# %%
#importing the file
data_df = pd.read_csv('/content/Crime.csv')
data_df.head()
# Out:
#     X1   X2  X3  X4  X5  X6  X7
# 0  478  184  40  74  11  31  20
# 1  494  213  32  72  11  43  18
# 2  643  347  57  70  18  16  16
# 3  341  565  31  71  11  25  19
# 4  773  327  67  72   9  29  24

# %%
# 3priting the shape
print('Shape :',data_df.shape)
# Out:
# Shape : (50, 7)

# %%
#printing about the table
data_df.describe()
# Out:
#                 X1           X2         X3         X4         X5         X6  \
# count    50.000000    50.000000  50.000000  50.000000  50.000000  50.000000
# mean    717.960000   616.180000  37.760000  58.800000  15.400000  29.900000
# std     293.938766   573.739175  13.820364   9.965246   6.023762  14.801062
# min     341.000000    29.000000  16.000000  42.000000   4.000000   7.000000
# 25%     497.000000   230.750000  30.000000  49.000000  11.000000  21.250000
# 50%     654.500000   454.000000  34.500000  59.000000  14.000000  25.000000
# 75%     820.500000   822.500000  42.250000  67.000000  19.000000  34.250000
# max    1740.000000  3545.000000  86.000000  81.000000  34.000000  81.000000
#
#               X7
# count  50.000000
# mean   13.820000
# std     5.157479
# min     8.000000
# 25%    11.000000
# 50%    12.000000
# 75%    15.750000
# max    36.000000

# %%
#checking Nan values in python
data_df.isnull().values.any()
# Out:
# False

# %%
data_df.rename(columns={"X1":"City","X2":"City1","X3":"City2","X4":"City3","X4":"City4","X5":"City4","X6":"City6"})
data_df.head()
# Out:
#     X1   X2  X3  X4  X5  X6  X7
# 0  478  184  40  74  11  31  20
# 1  494  213  32  72  11  43  18
# 2  643  347  57  70  18  16  16
# 3  341  565  31  71  11  25  19
# 4  773  327  67  72   9  29  24

# %%
#Matplotlib  type 1
import matplotlib.pyplot as plt
import seaborn; 

plt.hist(data_df)
plt.title("Cities Crime")
plt.xlabel('City')
plt.ylabel('Number');

# %%
#Matplotlib type2 - scatter plot
data_df.plot(figsize=(20,10), kind='line',x=0, y=1) # scatter plot

# %%
x_train_skl, x_test_skl = train_test_split(data_df,test_size = 0.20, random_state=99)
x_test_skl
# Out:
#      X1    X2  X3  X4  X5  X6  X7
# 16  457   118  29  64  12  21  10
# 32  652   630  29  47  19  25   9
# 13  491   809  32  67  11  37  16
# 11  819   369  30  81   4  77  36
# 28  912  1017  27  44  21  24   9
# 22  623   254  38  54  20  22  11
# 38  989  1375  22  49   9  46  13
# 36  657   879  33  72  13  13  22
# 21  357   218  35  54  14  27  13
# 44  863   601  20  69  23   7  12

# %%
#Linear regression 
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
#Training with prediction 
# #Building the Decision Tree Model on our dataset
# from sklearn.tree import DecisionTreeRegressor
# DT_model = DecisionTreeRegressor(max_depth=100).fit(x_train_skl,x_test_skl)
# DT_predict = DT_model.predict(x_train_skl) #Predictions on Testing data
# print(DT_predict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-625442b70de4> in <module>
#       2 #Building the Decision Tree Model on our dataset
#       3 from sklearn.tree import DecisionTreeRegressor
# ----> 4 DT_model = DecisionTreeRegressor(max_depth=100).fit(x_train_skl,x_test_skl)
#       5 DT_predict = DT_model.predict(x_train_skl) #Predictions on Testing data
#       6 print(DT_predict)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1318             sample_weight=sample_weight,
#    1319             check_input=check_input,
# -> 1320             X_idx_sorted=X_idx_sorted,
#    1321         )
#    1322         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
# ...

# %%
#Mean squared error
from sklearn.metrics import mean_squared_error
  
# Given values
Y_true = [1,1,2,2,4]  # Y_true = Y (original values)
  
# calculated values
Y_pred = [0.6,1.29,1.99,2.69,3.4]  # Y_pred = Y'
  
# Calculation of Mean Squared Error (MSE)
mean_squared_error(Y_true,Y_pred)
# Out:
# 0.21606
