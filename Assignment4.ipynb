# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravkeerat02/comp3122_labs/blob/master/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
#downloading and storing the file
df = pd.read_csv('/content/test(1).csv')

# %%
#showing top 3 rows
df.head(3)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50    F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21    M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America

# %%
#delete model 
df.drop('Model',axis=1)
# Out:
#        ID  Range  Value Type Zip Code   Cost      Continent
# 0      10    192     50    F   NXEYEM  [56$]           Asia
# 1      20    299     21    M   VNFKZD  [18$]           Asia
# 2      30    378     28    X   IMGMFY  [90$]  North America
# 3      40    156     44    Q   RHRHJY  [89$]           Asia
# 4      50    468     33    J   HPQCMC  [95$]         Africa
# ..    ...    ...    ...  ...      ...    ...            ...
# 945  9460    136     12    C   HGVBPV  [51$]  South America
# 946  9470    316     46    L   SHBAUD  [33$]  North America
# 947  9480    461     46    K   PUZUVO  [12$]         Europe
# 948  9490    185     13    N   UMESZO  [39$]  North America
# 949  9500    137     10    W   JOHHVL  [10$]  South America
#
# [950 rows x 7 columns]

# %%
# df.dropna('Model') 
# # - deleting permanenetly

# %%
#delete rows
# df.drop('1','3','5')

# %%
drop_df = pd.read_csv('/content/test(1).csv')
drop_df.drop([1,3,5],axis=0,inplace=True)
drop_df.head(4)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50    F   NXEYEM  EX85  [56$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America
# 4  50    468     33    J   HPQCMC  QX90  [95$]         Africa
# 6  70    327     24    F   NLVQPY  JY72  [25$]         Europe

# %%
#calculating mean in Range
mean_df = np.mean(df['Range'])
print(mean_df)
# Out:
# 297.4378947368421

# %%
#coutning F in the rows
df.Type.value_counts()['F']
replace_df = df.replace('F','AAA')
replace_df.head(5)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50  AAA   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21    M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America
# 3  40    156     44    Q   RHRHJY  IR14  [89$]           Asia
# 4  50    468     33    J   HPQCMC  QX90  [95$]         Africa

# %%
#delete permanently
# drop_df = pd.read_csv('/content/test(1).csv')
# drop_df.drop([',','$','and'],axis=0,inplace=True)
# drop_df.head(4)

# %%
#changing cost data type 
# df = df.astype()

# %%
# drop_df.groupby('Continent').Cost.average()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-78d8bd7e5a43> in <module>
# ----> 1 drop_df.groupby('Continent').Cost.average()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     910
#     911         raise AttributeError(
# --> 912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#     914
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'average'

# %%
#Standard Deviation calucalted fot COST 
# drop_df.groupby('Continent').Cost.std()

# %%
#calculatign min , max and std

# %%
mean_df = np.mean(df['Continent'])
print(mean_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1602         try:
# -> 1603             x = float(x)
#    1604         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: 'AsiaAsiaNorth AmericaAsiaAfricaNorth AmericaEuropeAntarcticaSouth AmericaSouth AmericaSouth AmericaAustraliaAustraliaAsiaAustraliaAsiaAntarcticaNorth AmericaAfricaSouth AmericaAntarcticaAsiaEuropeAntarcticaAustraliaAntarcticaSouth AmericaAntarcticaAustraliaNorth AmericaAustraliaAfricaAntarcticaAsiaAntarcticaNorth AmericaAustraliaAustraliaNorth AmericaEuropeAfricaAustraliaAsiaEuropeAsiaSouth AmericaEuropeAntarcticaAustraliaEuropeNorth AmericaNorth AmericaAustraliaAustraliaAntarcticaAustraliaAsiaAustraliaEuropeAfricaSouth AmericaEuropeEuropeAsiaNorth AmericaAsiaAsiaNorth AmericaNorth AmericaAsiaAsiaEuropeNorth AmericaAfricaAfricaAntarcticaAntarcticaSouth AmericaNorth AmericaSouth AmericaNorth AmericaAsiaNorth AmericaAustraliaEuropeSouth AmericaSouth AmericaAustraliaAustraliaNorth AmericaAfricaEuropeAustraliaAfricaAntarcticaAsiaEuropeAfricaAsiaSouth AmericaSouth AmericaNorth AmericaAfricaNorth AmericaSouth AmericaAustraliaSouth AmericaAntarcticaNorth AmericaAsiaAntarcticaAntarcticaEuropeAustraliaAntarcticaNorth AmericaAsiaSouth AmericaAfricaAfricaAfricaAustraliaAfricaAntarcticaAsiaAfricaAntarcticaEuropeAfricaNorth AmericaAfricaNorth AmericaAfricaAntarcticaSouth AmericaNorth AmericaAfricaNorth AmericaAsiaAsiaAustraliaEuropeAsiaAsiaAustraliaAfricaNorth AmericaAfricaAntarcticaSouth AmericaEuropeAntarcticaAntarcticaAfricaAustraliaAntarcticaAustraliaEuropeNorth AmericaAsiaEuropeAustraliaAntarcticaAsiaAsiaAfricaAustraliaAsi...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1606             try:
# -> 1607                 x = complex(x)
#    1608             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ce19c36ff844> in <module>
# ----> 1 mean_df = np.mean(df['Continent'])
#       2 print(mean_df)
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3436             pass
#    3437         else:
# -> 3438             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3439
#    3440     return _methods._mean(a, axis=axis, dtype=dtype,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1608             except ValueError as err:
#    1609                 # e.g. "foo"
# -> 1610                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1611     return x
#    1612
#
# TypeError: Could not convert AsiaAsiaNorth AmericaAsiaAfricaNorth AmericaEuropeAntarcticaSouth AmericaSouth AmericaSouth AmericaAustraliaAustraliaAsiaAustraliaAsiaAntarcticaNorth AmericaAfricaSouth AmericaAntarcticaAsiaEuropeAntarcticaAustraliaAntarcticaSouth AmericaAntarcticaAustraliaNorth AmericaAustraliaAfricaAntarcticaAsiaAntarcticaNorth AmericaAustraliaAustraliaNorth AmericaEuropeAfricaAustraliaAsiaEuropeAsiaSouth AmericaEuropeAntarcticaAustraliaEuropeNorth AmericaNorth AmericaAustraliaAustraliaAntarcticaAustraliaAsiaAustraliaEuropeAfricaSouth AmericaEuropeEuropeAsiaNorth AmericaAsiaAsiaNorth AmericaNorth AmericaAsiaAsiaEuropeNorth AmericaAfricaAfricaAntarcticaAntarcticaSouth AmericaNorth AmericaSouth AmericaNorth AmericaAsiaNorth AmericaAustraliaEuropeSouth AmericaSouth AmericaAustraliaAustraliaNorth AmericaAfricaEuropeAustraliaAfricaAntarcticaAsiaEuropeAfricaAsiaSouth AmericaSouth AmericaNorth AmericaAfricaNorth AmericaSouth AmericaAustraliaSouth AmericaAntarcticaNorth AmericaAsiaAntarcticaAntarcticaEuropeAustraliaAntarcticaNorth AmericaAsiaSouth AmericaAfricaAfricaAfricaAustraliaAfricaAntarcticaAsiaAfricaAntarcticaEuropeAfricaNorth AmericaAfricaNorth AmericaAfricaAntarcticaSouth AmericaNorth AmericaAfricaNorth AmericaAsiaAsiaAustraliaEuropeAsiaAsiaAustraliaAfricaNorth AmericaAfricaAntarcticaSouth AmericaEuropeAntarcticaAntarcticaAfricaAustraliaAntarcticaAustraliaEuropeNorth AmericaAsiaEuropeAustraliaAntarcticaAsiaAsiaAfricaAustraliaAsiaAfricaAsiaAfricaSo...
