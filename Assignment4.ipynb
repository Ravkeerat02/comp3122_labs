# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravkeerat02/comp3122_labs/blob/master/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
#downloading and storing the file
df = pd.read_csv('/content/test(1).csv')

# %%
#showing top 3 rows
df.head(3)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50    F   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21    M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America

# %%
#delete model 
df.drop('Model',axis=1)
# Out:
#        ID  Range  Value Type Zip Code   Cost      Continent
# 0      10    192     50    F   NXEYEM  [56$]           Asia
# 1      20    299     21    M   VNFKZD  [18$]           Asia
# 2      30    378     28    X   IMGMFY  [90$]  North America
# 3      40    156     44    Q   RHRHJY  [89$]           Asia
# 4      50    468     33    J   HPQCMC  [95$]         Africa
# ..    ...    ...    ...  ...      ...    ...            ...
# 945  9460    136     12    C   HGVBPV  [51$]  South America
# 946  9470    316     46    L   SHBAUD  [33$]  North America
# 947  9480    461     46    K   PUZUVO  [12$]         Europe
# 948  9490    185     13    N   UMESZO  [39$]  North America
# 949  9500    137     10    W   JOHHVL  [10$]  South America
#
# [950 rows x 7 columns]

# %%
# df.dropna('Model') 
# # - deleting permanenetly

# %%
#delete rows
# df.drop('1','3','5')

# %%
drop_df = pd.read_csv('/content/test(1).csv')
drop_df.drop([1,3,5],axis=0,inplace=True)
drop_df.head(4)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50    F   NXEYEM  EX85  [56$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America
# 4  50    468     33    J   HPQCMC  QX90  [95$]         Africa
# 6  70    327     24    F   NLVQPY  JY72  [25$]         Europe

# %%
#calculating mean in Range
mean_df = np.mean(df['Range'])
print(mean_df)
# Out:
# 297.4378947368421

# %%
#coutning F in the rows
df.Type.value_counts()['F']
replace_df = df.replace('F','AAA')
replace_df.head(5)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50  AAA   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21    M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America
# 3  40    156     44    Q   RHRHJY  IR14  [89$]           Asia
# 4  50    468     33    J   HPQCMC  QX90  [95$]         Africa

# %%
#delete permanently
# drop_df = pd.read_csv('/content/test(1).csv')
# drop_df.drop([',','$','and'],axis=0,inplace=True)
# drop_df.head(4)

# %%
#changing cost data type 
# df = df.astype()

# %%
# drop_df.groupby('Continent').Cost.average()

# %%
#Standard Deviation calucalted fot COST 
# drop_df.groupby('Continent').Cost.std()

# %%
#calculatign min , max and std

# %%
# mean_df = np.mean(df['Continent'])
# print(mean_df)

# %%
#Calcualting mean of Continent
df.groupby('Continent').mean()
# Out:
#                         ID       Range      Value
# Continent
# Africa         4797.692308  282.475524  30.517483
# Antarctica     4569.310345  288.698276  30.344828
# Asia           4268.320611  284.038168  26.862595
# Australia      4677.323944  305.894366  30.063380
# Europe         5078.848921  320.338129  31.712230
# North America  4873.125000  300.159722  29.847222
# South America  4963.851852  298.422222  30.133333

# %%
#plotting the bar  chart 
# %matplotlib inline 
df.groupby('Continent').mean().plot(kind='bar')

# %%
#Number of each continet
df.Continent.value_counts()
# Out:
# North America    144
# Africa           143
# Australia        142
# Europe           139
# South America    135
# Asia             131
# Antarctica       116
# Name: Continent, dtype: int64

# %%
# df.Continent.value_counts()
# Out:
#   File "<ipython-input-22-d9f02d505499>", line 1
#     df.Continent.value_counts(%)
#                               ^
# SyntaxError: invalid syntax

# %%
#Finding out the unique problems
sorted(df.Continent.unique())
df.Continent.head()
# Out:
# 0             Asia
# 1             Asia
# 2    North America
# 3             Asia
# 4           Africa
# Name: Continent, dtype: object

# %%
#Value count for cost and describing the output 
df.Cost.value_counts()
# Out:
# [56$]    20
# [35$]    20
# [73$]    18
# [54$]    17
# [97$]    17
#          ..
# [30$]     5
# [77$]     5
# [92$]     5
# [42$]     3
# [24$]     2
# Name: Cost, Length: 90, dtype: int64

# %%
df.describe()
# Out:
#                 ID       Range       Value
# count   950.000000  950.000000  950.000000
# mean   4755.000000  297.437895   29.943158
# std    2743.856775  115.828540   12.267347
# min      10.000000  100.000000   10.000000
# 25%    2382.500000  194.000000   19.000000
# 50%    4755.000000  296.000000   30.000000
# 75%    7127.500000  398.750000   41.000000
# max    9500.000000  500.000000   50.000000

# %%
#plotting histogram 
df.groupby('Cost').mean().plot(kind='hist')

# %%
#finding the missing value
print(df.isnull().all())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7d40d3865641> in <module>
#       1 #finding the missing value
# ----> 2 print(df.isnull(Cost).all())
#
# NameError: name 'Cost' is not defined

# %%
#Statistics 
df.describe()
# Out:
#                 ID       Range       Value
# count   950.000000  950.000000  950.000000
# mean   4755.000000  297.437895   29.943158
# std    2743.856775  115.828540   12.267347
# min      10.000000  100.000000   10.000000
# 25%    2382.500000  194.000000   19.000000
# 50%    4755.000000  296.000000   30.000000
# 75%    7127.500000  398.750000   41.000000
# max    9500.000000  500.000000   50.000000

# %%
df.Type.value_counts()['F']
replace_df = df.replace('F','XXX')
replace_df.head(5)
# Out:
#    ID  Range  Value Type Zip Code Model   Cost      Continent
# 0  10    192     50  XXX   NXEYEM  EX85  [56$]           Asia
# 1  20    299     21    M   VNFKZD  CT41  [18$]           Asia
# 2  30    378     28    X   IMGMFY  VN81  [90$]  North America
# 3  40    156     44    Q   RHRHJY  IR14  [89$]           Asia
# 4  50    468     33    J   HPQCMC  QX90  [95$]         Africa
