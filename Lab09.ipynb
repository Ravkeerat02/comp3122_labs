# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravkeerat02/comp3122_labs/blob/master/Lab09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
oDF = pd.read_table('/content/OstapDS.tsv',sep="\t")

# %%
oDF.head()
# Out:
#     Nane LastName        StID
# 0   Reza    Dibaj  1012974533
# 1  Ronak     Gala  1015821478

# %%
rDF = pd.read_table('/content/RaufDS.csv',sep=",")

# %%
rDF.head()
# Out:
#     Nane LastName        StID
# 0   Reza    Dibaj  1012974533
# 1  Ronak     Gala  1015821478

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.shape
# Out:
# (4622, 5)

# %%
pd.read_table("http://bit.ly/movieusers", sep="|", header = None)
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
user_cols = ["user_id", "age", "gender", "occupation", "zip_code"]

# %%
users = pd.read_table("http://bit.ly/movieusers", sep="|", header = None, names = user_cols)

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo["Location"] = ufo["City"] + ", " + ufo["State"]

# %% [markdown]
# Creating Pandas seroes in DatFrame

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
ufo.zone = ufo["City"] + ", " + ufo["State"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# Methods - uses () for actions
#
# Attributes - doesnt have ()

# %%
movies.describe(include=["object"])
#Gives detail information about the table and tells what all is included
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
ufo_cols = ["city", "color reported", "shape reported", "state", "time"]

# %%
ufo = pd.read_csv("http://bit.ly/uforeports", names = ufo_cols, header = 0)

# %%
ufo.head()
# Out:
#                    city color reported shape reported state             time
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns = ufo.columns.str.replace(" ", "_")

# %%
ufo.columns
# Out:
# Index(['city', 'color_reported', 'shape_reported', 'state', 'time'], dtype='object')

# %%
ufo.drop("color_reported", axis = 1, inplace = True)

# %%
ufo.head()
# Out:
#                    city shape_reported state             time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 4)

# %%
ufo.head()
# Out:
#                    city shape_reported state             time
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00
# 5           Valley City           DISK    ND  9/15/1934 15:30
# 6           Crater Lake         CIRCLE    CA   6/15/1935 0:00

# %% [markdown]
# Inplace - returns copy of an object

# %%
ufo.shape
# Out:
# (18237, 4)
